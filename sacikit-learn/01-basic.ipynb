# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('tips')
df.head()
# df['smoker_num'] = df['smoker'].map({'Yes':1, 'No':0})
X = df[['total_bill','size']]
Y = df['tip']

# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)


# call the model
model = LinearRegression()
model.fit(X_train, Y_train)
# model.predict(X_test)

# metrices to evalute the model 
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
Y_pred = model.predict(X_test)

print(f"Mean squared error: {mean_squared_error(Y_test, Y_pred)}")
print(f"r2_score: {r2_score(Y_test, Y_pred)}")
print(f"mean_absolute_error: {mean_absolute_error(Y_test, Y_pred)}")

# with numpy
print(f"mean_absolute_error: {np.sqrt(mean_absolute_error(Y_test, Y_pred))}")
# Out:
# Mean squared error: 1.0909631192427636
# r2_score: 0.5230010817048678
# mean_absolute_error: 0.7591592373810476
# mean_absolute_error: 0.8712974448378967
