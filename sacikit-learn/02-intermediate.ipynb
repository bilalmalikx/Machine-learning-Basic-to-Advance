# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# load the data

df = sns.load_dataset('tips')
df.head()
df['smoker_num'] = df['smoker'].map({'Yes' : 1, 'No' : 0})
df.head()
X = df[['total_bill', 'size', 'smoker_num']]
Y = df['tip']

model = LinearRegression()
model.fit(X, Y)
print(model.predict([[35.59, 2, 1]]))
print(model.predict([[35.59, 2, 0]]))
# Out:
# [4.32773388]
# [4.41116643]
# /Users/bilalmalik/miniconda3/envs/ml_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/bilalmalik/miniconda3/envs/ml_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = sns.load_dataset('tips')
df.head()
X = df[['total_bill', 'size', 'tip']]
Y = df['smoker']

model = LogisticRegression()
model.fit(X, Y)
model.predict([[35.555, 2, 5]])
# Out:
# /Users/bilalmalik/miniconda3/envs/ml_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
import numpy as np 
import pandas as pd
